# %% [markdown]
# ## Google Colab

# %%
import os

# Run this cell to mount Google Drive for Colab
from google.colab import drive
drive.mount('/content/drive/')

if not os.path.exists('/home/odin'):
    # !cp -r '/content/drive/My Drive/Colab Notebooks/odin' '/home'
    # !tar -xvf '/home/odin/data/cifar-10-python.tar.gz' -C '/home/odin/data'
    # !tar -xvf '/home/odin/data/densenet10.pth.tar.gz' -C '/home/odin/data'
    # !tar -xvf '/home/odin/data/Imagenet.tar.gz' -C '/home/odin/data'

os.chdir('/home/odin')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# PyTorch has to be v0.3.1
# !pip3 uninstall torch
# !pip3 uninstall torchvision
# !pip3 install torch==0.3.1 -f https://download.pytorch.org/whl/cu100/stable
# !pip3 install torchvision==0.2.0

# %%
import torch
import torchvision

# !python3 --version

print('\nPyTorch: ', torch.__version__)

print('\ntorchvision: ', torchvision.__version__)

print('\nNVIDIA:')
# !nvcc --version
# !nvidia-smi
# Out:
# Python 3.6.8
#
# PyTorch:  0.3.1
#
# torchvision:  0.2.0
#
# NVIDIA:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130
# Thu Jul 25 20:05:32 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    74W / 149W |    378MiB / 11441MiB |      0%      Default |
# ...

# %%
import os
import cal as c

os.chdir('/home/odin/code')

c.test('densenet10', 'Imagenet', 0, 0.0014, 1000)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:325: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:325: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...

# %%
# !cp -r '/home/odin/code/softmax_scores' '/content/drive/My Drive/Colab Notebooks/odin/code'

# !mv /calData.py /home/odin/code/calData.py
